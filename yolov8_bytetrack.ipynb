# %% [markdown]
# # yolo v8 + Bytetrackで物体追尾実験

# %%
import os
os.chdir('../yolov8-learning/ultralytics')
path = os.getcwd()
print(path)
# Out:
# /work/kosuge/M1/yolov8-learning/ultralytics

# %%
from ultralytics import YOLO

# Load an official or custom model
model = YOLO('yolov8n.pt')  
# Load an official Detect model

# Perform tracking with the model
results = model.track(source="movie/palace.mp4", show=True, tracker="bytetrack.yaml",save = True)  # Tracking with ByteTrack tracker
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#  ---------------------Bytetrack Tracking Start--------------------------
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/329) /work/kosuge/M1/yolov8-learning/ultralytics/movie/palace.mp4: 384x640 8 persons, 1 handbag, 15.9ms
# video 1/1 (2/329) /work/kosuge/M1/yolov8-learning/ultralytics/movie/palace.mp4: 384x640 8 persons, 1 handbag, 10.3ms
# ...
