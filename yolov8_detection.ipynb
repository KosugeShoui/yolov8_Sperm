# %% [markdown]
# # 学習済のyolo v8モデルで推論する

# %% [markdown]
# ## visem で推論

# %%
cd ultralytics
# Out:
# /work/kosuge/M1/yolov8_sperm_learning/ultralytics

# %% [markdown]
# kosuge/M1/yolov8_sperm_learning/ultralytics/runs/visem_detect

# %%
exp_name = 'train_1024_visem'

# %%
from ultralytics import YOLO

# %%
model = YOLO('runs/visem_detect/' + exp_name + '/weights/best.pt')

# %%
#動画のパスを指定
data_path = 'movie/52.mp4'

#保存する場所を指定しておくといい
model(source = data_path ,save=True, conf=0.3, iou=0.4,show = True,name = '../visem_detect/test')
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
#
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/1440) /work/kosuge/M1/yolov8_sperm_learning/ultralytics/movie/52.mp4: 480x640 13 Sperms, 19.9ms
# video 1/1 (2/1440) /work/kosuge/M1/yolov8_sperm_learning/ultralytics/movie/52.mp4: 480x640 12 Sperms, 13.5ms
# video 1/1 (3/1440) /work/kosuge/M1/yolov8_sperm_learning/ultralytics/movie/52.mp4: 480x640 11 Sperms, 12.6ms
# ...
