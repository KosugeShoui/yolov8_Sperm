# %%
cd ultralytics
# Out:
# /work/kosuge/M1/yolov8_sperm_learning/ultralytics

# %%
import os

path = os.getcwd()

print(path)
# Out:
# /work/kosuge/M1/yolov8_sperm_learning/ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")
model.train(data="../../Mini_OneDice_Otsu/OneDice_Otsu.yaml", epochs=500, batch=16, workers=0,name = '../signate/train_1104_onedice',patience = 200,dropout = 0.5)
# Out:
# Ultralytics YOLOv8.0.149 🚀 Python-3.8.10 torch-1.13.0+cu117 CUDA:0 (NVIDIA TITAN X (Pascal), 12194MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
metrics = model.val(
    data="/Users/hinomaruc/Desktop/blog/dataset/aidetection_test/test.yaml",
    split='val', conf=0.001, iou=0.6,
    project="/Users/hinomaruc/Desktop/blog/dataset/yolov8/runs",
    name="test_val",
    exist_ok=True,
    half=True, # default=True
    save_json=True
)
