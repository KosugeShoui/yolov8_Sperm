# %% [markdown]
# # 学習済のyolo v8モデルで推論する

# %%
cd ultralytics
# Out:
# /work/kosuge/M1/yolov8_sperm_learning/ultralytics

# %%
exp_name = 'train_0809_x'

# %%
from ultralytics import YOLO

# %%
model = YOLO('runs/detect/' + exp_name + '/weights/best.pt')

# %%
data_path = 'large_image'
model(source = data_path ,save=True, conf=0.4, iou=0.2,show = True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/5 /work/kosuge/M1/yolov8_sperm_learning/ultralytics/large_image/201_000.jpg: 480x640 1 Sperm, 5 BlurredSperms, 29.8ms
# image 2/5 /work/kosuge/M1/yolov8_sperm_learning/ultralytics/large_image/image.png: 608x640 (no detections), 36.0ms
# image 3/5 /work/kosuge/M1/yolov8_sperm_learning/ultralytics/large_image/image2.png: 608x640 (no detections), 35.1ms
# image 4/5 /work/kosuge/M1/yolov8_sperm_learning/ultralytics/large_image/image3.png: 416x640 1 Sperm, 3 BlurredSperms, 28.1ms
# image 5/5 /work/kosuge/M1/yolov8_sperm_learning/ultralytics/large_image/image4.png: 512x640 (no detections), 30.7ms
# Speed: 2.2ms preprocess, 31.9ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to runs/detect/predict14
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
# ...
