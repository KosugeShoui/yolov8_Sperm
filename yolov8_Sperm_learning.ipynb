# %% [markdown]
# # yolov8を精子のデータセットでFine tuning

# %%
cd ultralytics
# Out:
# /work/kosuge/M1/yolov8_sperm_learning/ultralytics

# %%
import os
path = os.getcwd()
print(path)
# Out:
# /work/kosuge/M1/yolov8_sperm_learning/ultralytics

# %% [markdown]
# ## train
# - モデルの重み指定、degreeはデータ拡張、画像をランダムに0から90度回転させる
# - 結果はruns/detect/trainに保存

# %% [markdown]
# model = YOLO("yolov8n.pt")
# model.train(data="../../Image_label/data_0512.yaml", epochs=500, batch=8, workers=0,name = 'train_1020_s_cj',patience = 200,
#            dropout = 0.5)

# %% [markdown]
# ### 通常データでの学習
# - augment = Trueでデータ拡張が入る
# - hsv, degree, translate, scale, shear, perspective, flip, mosaic, mixup

# %%
from ultralytics import YOLO
model = YOLO("yolov8l.pt")
model.train(data="../../Image_label_normal/data.yaml", epochs=500, batch=8, workers=0,
            name = '../detection_for_gradingapp/train_1119',patience = 200,dropout = 0.5,save_crop = False,augment = True,
           cos_lr = True, exist_ok = True)
# Out:
# Ultralytics YOLOv8.0.149 🚀 Python-3.8.10 torch-1.13.0+cu117 CUDA:0 (NVIDIA TITAN X (Pascal), 12194MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %% [markdown]
# ## testデータによる評価

# %% [markdown]
# ### argment
# - https://docs.ultralytics.com/modes/val/#usage-examples

# %%
#validate the model
metric = model.val()
metric.box.map
metric.box.map50
metric.box.map75
metric.box.maps
# Out:
# Ultralytics YOLOv8.0.149 🚀 Python-3.8.10 torch-1.13.0+cu117 CUDA:0 (NVIDIA TITAN X (Pascal), 12194MiB)
# Model summary (fused): 268 layers, 43608921 parameters, 0 gradients, 164.8 GFLOPs
# val: Scanning /work/kosuge/M1/yolov8_sperm_learning/ultralytics/Image_label_normal/val/labels.cache... 112 images, 0 backgrounds, 0 corrupt: 100% 112/112 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 14/14 [00:15<00:00,  1.08s/it]
#                    all        112        507      0.564      0.619      0.579      0.292
#                  Sperm        112        323      0.682      0.864      0.852      0.499
#               NonSperm        112        108      0.536      0.389      0.381      0.158
#           BlurredSperm        112         76      0.473      0.605      0.504       0.22
# Speed: 0.1ms preprocess, 38.0ms inference, 0.0ms loss, 0.6ms postprocess per image
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir ultralytics/runs  # replace with 'runs' directory
# Out:
#       <iframe id="tensorboard-frame-f1d2ee2700b353e9" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f1d2ee2700b353e9");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
# wandb: Network error (TransientError), entering retry loop.
# wandb: Network error (TransientError), entering retry loop.
# wandb: Network error (TransientError), entering retry loop.
# wandb: Network error (TransientError), entering retry loop.
# wandb: Network error (TransientError), entering retry loop.
# wandb: Network error (SSLError), entering retry loop.
# wandb: Network error (SSLError), entering retry loop.
# wandb: Network error (SSLError), entering retry loop.
# wandb: Network error (SSLError), entering retry loop.
# ...
